# %% [markdown]
# # Assignment 5 Demo

# %% [markdown]
# ### Veo 3

# %%
# Generated by GPT-5 (medium reasoning) Via Windsurf
# Prompt: How can I insert @Screenshot 2025-10-02 at 5.06.19 PM.png 
# into my jupyter notebook? Can you generate code to do this?

from IPython.display import Image, display
from pathlib import Path

# Find the file robustly (handles the special space before "PM")
img_path = next(Path('.').glob('Screenshot 2025-10-02 at 5.06.19*PM.png'))
display(Image(filename=str(img_path), width=900))  # adjust width as needed

# %% [markdown]
# Veo 3 is simple to generate a video with, however it requires a Google Gemini Pro subscription.

# %%
# Generated by GPT-5 (medium reasoning) Via Windsurf
# Prompt: Thanks what about the video @veo3.mp4 ?

from IPython.display import Video, display
from pathlib import Path

video_path = Path('veo3.mp4')  # relative to the notebook
display(Video(filename='veo3.mp4', embed=False, width=900,
              html_attributes="controls autoplay loop muted playsinline"))
# Out:
# <video src="veo3.mp4" controls autoplay loop muted playsinline  width="900" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# As you can see, the video is good quality. It is clearly an AI generated video, but it looks good.

# %% [markdown]
# ### Wan2.2 14B Q4 K S

# %%
from IPython.display import Image, display
from pathlib import Path

# Find the file robustly (handles the special space before "PM")
img_path = next(Path('.').glob('Screenshot 2025-10-02 at 5.03.58*PM.png'))
display(Image(filename=str(img_path), width=900))  # adjust width as needed

# %% [markdown]
# This is much more complicated to generate a video and takes substantially longer, however a template is provided, and the exact workflow configuration that I used is available in this folder: assignment_5/video_wan2_2_14B_t2v_custom.json

# %%
from IPython.display import Video, display
from pathlib import Path

video_path = Path('veo3.mp4')  # relative to the notebook
display(Video(filename='wan2_2_14B_Q4_K_S.mp4', embed=False, width=500,
              html_attributes="controls autoplay loop muted playsinline"))
# Out:
# <video src="wan2_2_14B_Q4_K_S.mp4" controls autoplay loop muted playsinline  width="500" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# As can be seen above, the video is not good quality. It is low resolution and looks poor. I believe the flickering is due to the tiled decoding that occurs due to the memory limitation of my computer.

# %% [markdown]
# ### Wan2.2 14B

# %%
from IPython.display import Image, display
from pathlib import Path

# Find the file robustly (handles the special space before "PM")
img_path = next(Path('.').glob('Screenshot 2025-10-02 at 5.08.54*PM.png'))
display(Image(filename=str(img_path), width=900))  # adjust width as needed

# %% [markdown]
# The process of generating via Hugging Face is much more like generating using Veo 3 and only requires a Hugging Face account. However, there is much less control with this method.

# %%
from IPython.display import Video, display
from pathlib import Path

video_path = Path('veo3.mp4')  # relative to the notebook
display(Video(filename='wan2_2_14B.mp4', embed=False, width=900,
              html_attributes="controls autoplay loop muted playsinline"))
# Out:
# <video src="wan2_2_14B.mp4" controls autoplay loop muted playsinline  width="900" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# The video quality is much much better, however, it is not a toucan and is a monkey looking creature with a beak riding on a turtle with two heads. So while the water and tectures look good, there are clearly still issues.
